# %% [markdown]
# #**Data Toolkit Assignment**

# %% [markdown]
# ##**Theory Answer**

# %%
#Answer 1
"""
NumPy or numerical python is a powerful library in python.
It provides support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical
functions to operate on these arrays.
Numpy is widely used because:
1. Speed
2.Simplicity for scientific computation
3.Foundation of other libraries
4.Cross platfrom consistency"""
# Out:
# '\nNumPy or numerical python is a powerful library in python.\nIt provides support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical\nfunctions to operate on these arrays.\nNumpy is widely used because:\n1. Speed\n2.Simplicity for scientific computation\n3.Foundation of other libraries\n4.Cross platfrom consistency'

# %%
#Answer 2
"""
Broadcasting is NumPy is a mechanism that allows arrays with different shapes to be used together in arithmetic operations without
requiring explicit replication of data.
NumPy applies operations element wise, saving memory and improving efficiency.
"""
# Out:
# '\nBroadcasting is NumPy is a mechanism that allows arrays with different shapes to be used together in arithmetic operations without \nrequiring explicit replication of data.\nNumPy applies operations element wise, saving memory and improving efficiency.\n'

# %%
#Answer 3
"""
A Pandas dataframe is a two dimensional tabular data structure provided by the pandas library in python
It is one of the core data structure in pandas and isdesigned to make data manipulation and analysis intutive and efficient.
"""
# Out:
# '\nA Pandas dataframe is a two dimensional tabular data structure provided by the pandas library in python\nIt is one of the core data structure in pandas and isdesigned to make data manipulation and analysis intutive and efficient.\n'

# %%
#Answer 4
"""
The groupby() method in Pandas is a powerful tool used for grouping data and performing operation on thses groups.
It is commonly used for data aggregation, transformation and analysis, making it an essential method in data science and
EDA.
"""
# Out:
# '\nThe groupby() method in Pandas is a powerful tool used for grouping data and performing operation on thses groups.\nIt is commonly used for data aggregation, transformation and analysis, making it an essential method in data science and\nEDA.\n'

# %%
#Answer 5
"""
Seaborn is a python library built on top of Matplotlib that is widely used for statistical data visualization.
It is preferred for statistical visualization because od its ease of use, aesthetically pleasing visuals, and
built in support for complex statistical plots.
"""
# Out:
# '\nSeaborn is a python library built on top of Matplotlib that is widely used for statistical data visualization.\nIt is preferred for statistical visualization because od its ease of use, aesthetically pleasing visuals, and \nbuilt in support for complex statistical plots.\n'

# %%
#Answer 6
"""
NumPy arrays and Python lists are used to store collection of data, they differ significantly in terms of functionality,
performance and use cases.
NumPy array has homogeneous elements where as a list can have different types of elements in it.
NumPy Array are faster due to its implementation in C but Lists are slower
NumPy arrays are designed for numerical and scientific computations but general purpose of list is storing data.
"""
# Out:
# '\nNumPy arrays and Python lists are used to store collection of data, they differ significantly in terms of functionality, \nperformance and use cases.\nNumPy array has homogeneous elements where as a list can have different types of elements in it.\nNumPy Array are faster due to its implementation in C but Lists are slower \nNumPy arrays are designed for numerical and scientific computations but general purpose of list is storing data.\n'

# %%
#Answer 7
"""
A Heatmap is a data visualization technique that uses a grid of cell to represent data values with varying colors.
each cell's color intensity corresponding to the magnitude of a value, making it easy to identify patterns , correlations
and trends in complex datasets.
Heatmap is used to:
1.Explore Correlations
2.Analyzing large dataset
3.Identifying outliers.
4.Comparing Catagories
5.Cluster Analysis.
6.Time-Series Analysis.
"""
# Out:
# "\nA Heatmap is a data visualization technique that uses a grid of cell to represent data values with varying colors.\neach cell's color intensity corresponding to the magnitude of a value, making it easy to identify patterns , correlations \nand trends in complex datasets.\nHeatmap is used to:\n1.Explore Correlations\n2.Analyzing large dataset\n3.Identifying outliers.\n4.Comparing Catagories\n5.Cluster Analysis.\n6.Time-Series Analysis.\n"

# %%
#Answer 8
"""
Vectorized operation in NumPy refers to the ability to perform operations on entire arrays element wise without the
need for explicit loop in python.
"""
# Out:
# '\nVectorized operation in NumPy refers to the ability to perform operations on entire arrays element wise without the \nneed for explicit loop in python.\n'

# %%
#Answer 9
"""
Features                                  Matplotlib                                                  Plotly
Interactivity                   static by default                                   Interactive by default
Easy of Use                     requires more efforts for complex plots             Simple and intutive for advanced plots
Customization                   Extremely customizable                              High-level customization
Application                     Academic and scientific use                         Business intelligence & dashboard
Performance                     best for small datasets                             Handles large datasets well
Output                          static Images                                       Interactive & static exports
"""
# Out:
# '\nFeatures                                  Matplotlib                                                  Plotly\nInteractivity                   static by default                                   Interactive by default\nEasy of Use                     requires more efforts for complex plots             Simple and intutive for advanced plots\nCustomization                   Extremely customizable                              High-level customization\nApplication                     Academic and scientific use                         Business intelligence & dashboard\nPerformance                     best for small datasets                             Handles large datasets well\nOutput                          static Images                                       Interactive & static exports\n'

# %%
#Answer 10
"""
Hierarchical indexingin pandas is a powerful feature that allows you to work with data using multiple levels of indexing for rows and/or columns.
These complex data structures where data is indexed by more than one key.
"""
# Out:
# '\nHierarchical indexingin pandas is a powerful feature that allows you to work with data using multiple levels of indexing for rows and/or columns.\nThese complex data structures where data is indexed by more than one key.\n'

# %%
#Answer 11
"""
Key Roles of pairplot():
1.Visualizing pairwise relationship.
2.Showing Distributions.
3.Grouping by Categorical Variables.
4.Customizable Plot Elements.
"""
# Out:
# '\nKey Roles of pairplot():\n1.Visualizing pairwise relationship.\n2.Showing Distributions.\n3.Grouping by Categorical Variables.\n4.Customizable Plot Elements.\n'

# %%
#Answer 12
"""
The describe() function in pandas is used to generate summary statistics for numerical or categorical data in a dataframe
or series. It provides a quick overview of the dataset,including measures of central tendency,dispersion, and distribution.
"""
# Out:
# '\nThe describe() function in pandas is used to generate summary statistics for numerical or categorical data in a dataframe \nor series. It provides a quick overview of the dataset,including measures of central tendency,dispersion, and distribution.\n'

# %%
#Answer 13
"""
Handling missing data is important because:
1.Ensures Data Integrity
2.Maintains model accuracy
3.Enables consistent Data Analysis
4.Helps identify underlying issues
5.Preserves Data Usability
"""
# Out:
# '\nHandling missing data is important because:\n1.Ensures Data Integrity\n2.Maintains model accuracy\n3.Enables consistent Data Analysis\n4.Helps identify underlying issues\n5.Preserves Data Usability\n'

# %%
#Answer 14
"""
The benefits od using Plotly are as follow:
1.Interactivity
2.High-Quality Visuals
3.Broad Range of Charts
4.Cross Language Support
5.Easy integration with wen Application
6.Bult in Support for large datasets
7.Flexible and customizable
8.interactive dashboard
9.open source with enterprise
"""
# Out:
# '\nThe benefits od using Plotly are as follow:\n1.Interactivity\n2.High-Quality Visuals\n3.Broad Range of Charts\n4.Cross Language Support\n5.Easy integration with wen Application\n6.Bult in Support for large datasets\n7.Flexible and customizable\n8.interactive dashboard\n9.open source with enterprise\n'

# %%
#Answer 15
"""
NumPy handels multidimensional arrays efficiently using its 'ndarray' objects, which is a powerful data structure designed
for numerical computations.
"""
# Out:
# "\nNumPy handels multidimensional arrays efficiently using its 'ndarray' objects, which is a powerful data structure designed \nfor numerical computations.\n"

# %%
#Answer 16
"""
Bokeh is a powerful and interactive data visualization library in python.
Its primary role is to enable the creation the creation of rich, interactive and visually appealing visualizations thats
can be easily shared as standalone documents or embedded in web application.
"""
# Out:
# '\nBokeh is a powerful and interactive data visualization library in python.\nIts primary role is to enable the creation the creation of rich, interactive and visually appealing visualizations thats\ncan be easily shared as standalone documents or embedded in web application.\n'

# %%
#Answer 17
"""
'map()' works only on Pandas Series objects, applies a function element wise to each value in the series.
'apply()' works on both dataframe and series in pandas, applies a function along a specific axis of the dataframe or series.
"""
# Out:
# "\n'map()' works only on Pandas Series objects, applies a function element wise to each value in the series.\n'apply()' works on both dataframe and series in pandas, applies a function along a specific axis of the dataframe or series.\n"

# %%
#Answer 18
"""
Some of the advanced feature of NumPy are as follow:
1.Broadcasting
2.Universal Functions
3.Vectorization
4.Advanced indexing
5.Structured Arrays
6.Linear Algebra Function
7.Random number generation
"""
# Out:
# '\nSome of the advanced feature of NumPy are as follow:\n1.Broadcasting\n2.Universal Functions\n3.Vectorization\n4.Advanced indexing\n5.Structured Arrays\n6.Linear Algebra Function\n7.Random number generation\n'

# %%
#Answer 19
"""
Pandas simplifies time series analysis by providing a wide range of tools and functionalities specifically designed
for working with temporal data. Thess features makes it easy to manipulate, analyze and visualize time indexed data efficiently.
"""
# Out:
# '\nPandas simplifies time series analysis by providing a wide range of tools and functionalities specifically designed \nfor working with temporal data. Thess features makes it easy to manipulate, analyze and visualize time indexed data efficiently.\n'

# %%
#Answer 20
"""
A pivot table in Pandas is a powerful data manipulation tool that helps summarize,aggregate and analyze data in a tabular format.
It is especially useful for working with large datasets, enabling you to reorganize and extract meaningful insights from complex datasets.
"""
# Out:
# '\nA pivot table in Pandas is a powerful data manipulation tool that helps summarize,aggregate and analyze data in a tabular format.\nIt is especially useful for working with large datasets, enabling you to reorganize and extract meaningful insights from complex datasets.\n'

# %%
#Answer 21
"""
NumPy array slicing is faster then Python's list slicing because of foloowing:
1.Homogeneous data types
2.Memory Management
3.Vectorized Operations
4.Lower Level Implementation
5.Less Overhead
"""
# Out:
# "\nNumPy array slicing is faster then Python's list slicing because of foloowing:\n1.Homogeneous data types\n2.Memory Management\n3.Vectorized Operations\n4.Lower Level Implementation\n5.Less Overhead\n"

# %%
#Answer 22
"""
Seaborn is ideal for:
1.Exploring distribution and relationships within data.
2.Visualizing the relationship between categorical and numerical data.
3.Quickly producing aesthetically pleasing ststistical plots.
"""
# Out:
# '\nSeaborn is ideal for:\n1.Exploring distribution and relationships within data.\n2.Visualizing the relationship between categorical and numerical data.\n3.Quickly producing aesthetically pleasing ststistical plots.\n'

# %% [markdown]
# ###**Practical Answer**

# %%
#Answer 1
import numpy as np #importing NumPy as np
import random #importing library random
arr = np.random.randint(1,5,(3,3))#creating a 2d NumPy Array using random integers
print(arr)
print(arr.ndim)#checking the dimension of above array
sum_row = arr.sum(axis=1)#calculating sum of row elements
print(sum_row)
# Out:
# [[1 3 4]
#  [4 2 4]
#  [2 1 4]]
# 2
# [ 8 10  7]

# %%
#Answer 2
import pandas as pd #importing pandas as pd
import seaborn as sns #importing seaborn as sns
df = sns.load_dataset('tips')#calculating mean tip value
avr_tips = df.tip.mean()
print(avr_tips)
# Out:
# 2.99827868852459

# %%
#Answer 3
import pandas as pd #importing pandas as pd
import numpy as np #importing numpy as np
import matplotlib.pyplot as plt #importing matplotlib.pyplot as plt
plt.scatter(x='tip',y='total_bill',data=df)#creating a scatter plot
plt.show()

# %%
#Answer 4
st_correlation = df[['total_bill','tip','size']]#initilizing the variables
st_correlation.corr()#finding correlation between variables
sns.heatmap(st_correlation.corr(), annot = True)#ploting a heatmap
plt.show()

# %%
#Answer 5
import plotly.express as px
fig = px.bar(df, x = df['size'],y = df['total_bill'], color=df['tip'],pattern_shape=df['day'],facet_col=df['smoker'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Answer 6
data = {"k1":[1,2,3,4,5],"k2":[4,7,2,8,4],"k3":[9,8,3,7,4]}
df1 = pd.DataFrame(data)
df1['row_sum'] = df1.sum(axis=1)
print(df1)
# Out:
#    k1  k2  k3  row_sum
# 0   1   4   9       14
# 1   2   7   8       17
# 2   3   2   3        8
# 3   4   8   7       19
# 4   5   4   4       13

# %%
#Answer 7
arr1 = np.random.randint(1,5,(3,3))
print(arr1)
arr2 = np.random.randint(4,8,(3,3))
print(arr2)
arr3 = arr1 * arr2
print(arr3)
# Out:
# [[2 4 1]
#  [1 2 3]
#  [2 4 2]]
# [[4 6 4]
#  [5 5 5]
#  [7 6 5]]
# [[ 8 24  4]
#  [ 5 10 15]
#  [14 24 10]]

# %%
#Answer 8
x = [1,2,3,4,5,6,7,8,9] #creating variable for line plot
y1 = np.random.randn(9)#creating variable for line plot
y2 = np.random.randn(9)#creating variable for line plot
y3 = np.random.randn(9)#creating variable for line plot
y4 = np.random.randn(9)#creating variable for line plot
plt.plot(x,y1,label='y1')#line plot using matplotlib
plt.plot(x,y2,label='y2')#line plot using matplotlib
plt.plot(x,y3,label='y3')#line plot using matplotlib
plt.plot(x,y4,label='y4')#line plot using matplotlib
plt.title('Line Plot')#providing title to the plot
plt.xlabel('X-axis')# assigning label to x-axis
plt.ylabel('Y-axis')# assigning label to x-axis
plt.grid(True)
plt.legend()
plt.show()

# %%
#Answer 9
in_fo = {"Name":['stu1','stu2','stu3','stu4'],"marks":[75,65,85,95],"attendance":[100,97,45,88]}
df2 = pd.DataFrame(in_fo)
#To filter for student with more than 60% marks and 70% attendance
filtered_df = df2[(df2['marks'] > 60) & (df2['attendance'] > 70)]
print(filtered_df)
# Out:
#    Name  marks  attendance
# 0  stu1     75         100
# 1  stu2     65          97
# 3  stu4     95          88

# %%
#Answer 10
#from dataframe 'tips' we are plotting histogram for columns: 'total_bill','tip','size'
sns.histplot(df[['total_bill','tip','size']], bins=30, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#Answer 11
arr4 = np.random.randint(1,10,(3,3))# creating random arry
print(arr4)
arr5 = np.random.randint(1,10,(3,3))# creating random arry
print(arr5)
arr6 = arr4.dot(arr5)#applying matric multiplication
print(arr6)
# Out:
# [[6 3 9]
#  [3 9 6]
#  [5 8 1]]
# [[5 5 1]
#  [2 7 2]
#  [7 1 4]]
# [[99 60 48]
#  [75 84 45]
#  [48 82 25]]

# %%
#Answer 12
df11 ="/content/sample_data/california_housing_test.csv"#path for data
df12 = pd.read_csv(df11)#loading csv file using pandas
df12.head()#first 5 rows of data
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
#Answer 13
a = [1,2,3,4,5,6,7,8,9]
b = np.random.randn(9)
c = np.random.randn(9)
fig = px.scatter_3d(x=a,y=b,z=c)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
